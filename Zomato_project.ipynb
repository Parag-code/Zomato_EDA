# %% [markdown]
# # Zomato Data analysis project

# %% [markdown]
# Step 1 - Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 2- Read the dataset

# %%
df=pd.read_csv("C:\\Users\\parag\\Downloads\\Data Science Files\\Zomato data .csv")

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# # Data Cleaning & Data Preprocessing
# convert the data type of column -rate

# %%
def handleRate(value):
    value=str(value).split("/")
    value=value[0];
    return float(value)

df["rate"]=df["rate"].apply(handleRate)

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# # Type of Restaurant

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=df["listed_in(type)"])
plt.xlabel("Type of Restaurant")
plt.show()

# %% [markdown]
# conclusion - majority of the restaurant fallsn in dinning category

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_data=df.groupby("listed_in(type)")["votes"].sum()
result=pd.DataFrame({"votes":grouped_data})
plt.plot(result,c="brown",marker="o")
plt.xlabel("Type of Restaurant",c="red",size=20)
plt.ylabel("Votes",c="red",size=20)
# Out:
# Text(0, 0.5, 'Votes')

# %% [markdown]
# conclusion - dining restaurant has recieved maximum votes

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.hist(df["rate"],bins=5)
plt.title("ratings distribution")
plt.show()

# %% [markdown]
# conclusion - the majority restaurant received ratings frpm 3.5 to 4

# %% [markdown]
# # Average order spending by couples

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x = df['approx_cost(for two people)'])
plt.show()

# %% [markdown]
# conclusion - the majority of couples preferr restaurant with an approx cost of 300 rupees

# %% [markdown]
# # which mode received max ratings

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x=df["online_order"],y=df["rate"])
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# conclusion - offline order received lower rating in compare to online order

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
pivot_table=df.pivot_table(index="listed_in(type)",columns="online_order",aggfunc="size",fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt="d")
plt.title("Heatmap")
plt.xlabel("online_order")
plt.ylabel("listed_in(type)")
plt.show()

# %% [markdown]
# conclusion- Dining restaurants primarly accept offline orders whereas cafes primarly receive online orders. This suggests that clients prefer to place orders in person at restaurants , but prefer online ordering at cafes
